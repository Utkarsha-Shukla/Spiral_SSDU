# %%
import scipy.io as sio

# Load .mat file
mat = sio.loadmat('kspace_mask_r2.mat')

# See all variables stored in the .mat file
print(mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'mask'])

# %%
print(mat['mask'].shape)
# Out:
# (396, 768)
